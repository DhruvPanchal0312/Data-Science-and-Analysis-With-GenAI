# %% [markdown]
# # 🐼 Pandas - Class 4: Data Selection & Filtering
# Welcome to **Class 4** of our Pandas series. Today we’ll explore techniques to select and filter data in a DataFrame.

# %% [markdown]
# ## 1. Boolean Indexing & Conditional Selection
# - Use comparison operators to build conditions (e.g., `df['col'] > 50`).
# - Pass the condition inside `df[...]` to get matching rows.
# - Combine multiple conditions with `&` (AND), `|` (OR), and `~` (NOT).
# - Parentheses are required when combining conditions.

# %%
import pandas as pd

# Create dummy data
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma", "Frank", "Grace", "Henry"],
    "Age": [23, 25, 22, 24, 26, 21, 27, 23],
    "Score": [88, 75, 92, 85, 79, 90, 95, 82]
}
b = pd.DataFrame(data)
print(b)
print("=====================")
b[b['Score']>=90]
# Out:
#       Name  Age  Score
# 0    Alice   23     88
# 1      Bob   25     75
# 2  Charlie   22     92
# 3    David   24     85
# 4     Emma   26     79
# 5    Frank   21     90
# 6    Grace   27     95
# 7    Henry   23     82
# =====================
#       Name  Age  Score
# 2  Charlie   22     92
# 5    Frank   21     90
# 6    Grace   27     95

# %% [markdown]
# ## 2. Filtering Rows with Multiple Conditions
# - Combine two or more conditions to refine selection.
# - Remember to enclose each condition in parentheses.

# %%
b[(b['Score']>=90) & (b['Age']>23) ]
# Out:
#     Name  Age  Score
# 6  Grace   27     95

# %%
b[(b['Score']>=90) | (b['Age']>23) ]
# Out:
#       Name  Age  Score
# 1      Bob   25     75
# 2  Charlie   22     92
# 3    David   24     85
# 4     Emma   26     79
# 5    Frank   21     90
# 6    Grace   27     95

# %%
b[~(b['Score']>=90)]
# Out:
#     Name  Age  Score
# 0  Alice   23     88
# 1    Bob   25     75
# 3  David   24     85
# 4   Emma   26     79
# 7  Henry   23     82

# %% [markdown]
# ## 3. Using `query()` for Cleaner Filtering
# - `query()` allows filtering rows with a string expression.
# - It's concise and readable for complex conditions.
# - Variables can be passed using the `@` symbol.

# %%
b.query("Age> 25 and Score > 93")
hey=93
b.query("Age> 25 and Score > @hey")
# Out:
#     Name  Age  Score
# 6  Grace   27     95

# %% [markdown]
# ## 4. String Operations on Columns
# - Use the `.str` accessor for vectorized string methods.
# - Common methods: `contains`, `replace`, `startswith`, `endswith`, `lower`, `upper`.
# - Useful for cleaning or filtering text data.

# %%
b['Name'].str.contains('a','r')
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: Name, dtype: bool

# %%
b['Name'].str.upper()
# Out:
# 0      ALICE
# 1        BOB
# 2    CHARLIE
# 3      DAVID
# 4       EMMA
# 5      FRANK
# 6      GRACE
# 7      HENRY
# Name: Name, dtype: str

# %%
b['Name'].str.lower()
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4       emma
# 5      frank
# 6      grace
# 7      henry
# Name: Name, dtype: str

# %%
b['Name'].str.replace("Henry","Dhruv")
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4       Emma
# 5      Frank
# 6      Grace
# 7      Dhruv
# Name: Name, dtype: str

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns such as Name, Age, City, Score.
# 2. Use boolean indexing to select rows where Age > 25.
# 3. Filter rows where City is either 'Delhi' or 'Mumbai'.
# 4. Use query() to find rows with Score >= 85 and Age < 35.
# 5. Clean a text column using str.replace or str.lower.

# %%
# 1. Build a DataFrame with columns: Name, Age, City, Score
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [23, 25, 22, 24, 26],
    "City": ["Delhi", "Mumbai", "Pune", "Bangalore", "Ahmedabad"],
    "Score": [88, 75, 92, 85, 79]
}

c = pd.DataFrame(data)
c
# Out:
#       Name  Age       City  Score
# 0    Alice   23      Delhi     88
# 1      Bob   25     Mumbai     75
# 2  Charlie   22       Pune     92
# 3    David   24  Bangalore     85
# 4     Emma   26  Ahmedabad     79

# %%
# 2. Use boolean indexing to select rows where Age > 25
# Write your code here
c[c['Age']>25]
# Out:
#    Name  Age       City  Score
# 4  Emma   26  Ahmedabad     79

# %%
# 3. Filter rows where City is either 'Delhi' or 'Mumbai'
# Write your code here
c[(c['City']=="Delhi") | (c['City']=="Mumbai")]
# Out:
#     Name  Age    City  Score
# 0  Alice   23   Delhi     88
# 1    Bob   25  Mumbai     75

# %%
# 4. Use query() to find rows with Score >= 85 and Age < 35
# Write your code here

# %%
# 5. Clean a text column using str.replace or str.lower
# Example: convert City names to lowercase or replace "delhi" with "New Delhi"
# Write your code here

# %% [markdown]
# ---
# ## Summary
# - Learned to use boolean indexing and conditional selection.
# - Filtered rows with multiple conditions.
# - Used `query()` for clean filtering.
# - Applied string operations with the `.str` accessor.
